# %% [markdown]
# Script ejemplo de descarga de rasters de 8 bandas.
#
# Paquetes necesarios:
# - agrodigital_io
# - rioxarray
#
# Para instalarlos ejecutar una vez:
#
# pip install agrodigital_io rioxarray

# %%
# !pip install agrodigital_io rioxarray
# Out:
# ...
#   Using cached rioxarray-0.20.0-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached xarray-2025.12.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached rioxarray-0.20.0-py3-none-any.whl (62 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 3.3 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 2.7 MB/s  0:00:02 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.4/24.4 MB 2.7 MB/s  0:00:09 eta 0:00:01
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Using cached xarray-2025.12.0-py3-none-any.whl (1.4 MB)
# ...

# %% [markdown]
# Una vez instalado el paquete, puedes importar los diferentes modulos en tu código de la siguiente manera:
#
# ```python
# from agrodigital_io import AgroDigitalClient
# ```

# %%
from agrodigital_io import AgroDigitalClient
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from agrodigital_io import AgroDigitalClient
#
# ImportError: cannot import name 'AgroDigitalClient' from 'agrodigital_io' (unknown location)
